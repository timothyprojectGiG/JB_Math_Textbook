# %% [markdown]
# # 7. Mapping Famous Chicagoans

# %% [markdown]
# In the lab we will learn how to use Python to put information on a map of a geographical location.

# %% [markdown]
# <h4>Step One</h4>
# Let's' begin by importing data of some famous people born in Chicago.

# %%
import pandas as pd
Chi=pd.read_csv('chicagoans.csv')
Chi
# Out:
#              Name  Age Alive      Noted For           Place of Birth    Zip  \
# 0  Michelle Obama   56   yes     First Lady       Provident Hospital  60605
# 1  Robin Williams   63    no          Actor       St Luke's Hospital  60605
# 2     Walt Disney   65    no  Film Producer            149 Tripp Ave  60651
# 3   Bobby Fischer   64    no          Chess  Michael Reese  Hospital  60606
# 4    Isiah Thomas   59   yes     Basketball                West Side  60624
#
#          Lat        Lon                                 fun fact
# 0  41.802665 -87.613657        father worked at city water plant
# 1  41.863100 -87.623100  went to Julliard with Christopher Reeve
# 2  41.907879 -87.732594                            won 22 oscars
# 3  41.884116 -87.637656                    grandmaster at age 15
# 4  41.874827 -87.710075                   youngest of 9 children

# %% [markdown]
# Q1. How old was Bobby Fischer when he became a grandmaster?
# <hr>
# <h3> STEP TWO</h3>
# Let's use a Python library called folium to make a map of Chicago.

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /home/timothyprojectinfo/.local/lib/python3.9/site-packages (0.14.0)
# Requirement already satisfied: numpy in /home/timothyprojectinfo/.local/lib/python3.9/site-packages (from folium) (1.24.3)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.9/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: requests in /home/timothyprojectinfo/.local/lib/python3.9/site-packages (from folium) (2.31.0)
# Requirement already satisfied: branca>=0.6.0 in /home/timothyprojectinfo/.local/lib/python3.9/site-packages (from folium) (0.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/timothyprojectinfo/.local/lib/python3.9/site-packages (from requests->folium) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/timothyprojectinfo/.local/lib/python3.9/site-packages (from requests->folium) (2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/timothyprojectinfo/.local/lib/python3.9/site-packages (from requests->folium) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/timothyprojectinfo/.local/lib/python3.9/site-packages (from requests->folium) (1.26.16)

# %%
import folium # map rendering library
from folium.features import DivIcon #used to add popup info to a map
Chicago_map = folium.Map(location=[41.886456, -87.62325],  tiles="Stamen Toner", zoom_start=10)
Chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e45112c6a5e948692693a3eb0a1452b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e45112c6a5e948692693a3eb0a1452b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e45112c6a5e948692693a3eb0a1452b3 = L.map(
#                 &quot;map_e45112c6a5e948692693a3eb0a1452b3&quot;,
#                 {
#                     center: [41.886456, -87.62325],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1c5a0465d2140eade0ad59600a07da4 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e45112c6a5e948692693a3eb0a1452b3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Q2.
#
# Try adjusting the "zoom_start" value. What happens?
#
# What happens if you change the numbers in location=[41.886456, -87.62325]"

# %% [markdown]
# <hr>
# <h3> STEP THREE</h3>
# Let's add our data about famous Chicagoans to the map.

# %%
Chicago_map=folium.Map(location=[41.886456,-87.62325],tiles="Stamen Toner",zoom_start=10)
for i in Chi.index:
    p=[Chi.loc[i,"Lat"],Chi.loc[i,"Lon"]]
    folium.Marker(p,icon=DivIcon(
        icon_size=(100,0),
        icon_anchor=(0,8),
        html='<div style="font-size:20pt; color:red">'+str(Chi.loc[i,"Name"]) +'</div>',
            )).add_to(Chicago_map)
    Chicago_map.add_child(folium.CircleMarker(p, radius=1,color='red'))
Chicago_map.save("Chicagoans.html")
Chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9281869bf14b84cd9b4d63b1fc723c0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9281869bf14b84cd9b4d63b1fc723c0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9281869bf14b84cd9b4d63b1fc723c0f = L.map(
#                 &quot;map_9281869bf14b84cd9b4d63b1fc723c0f&quot;,
#                 {
#                     center: [41.886456, -87.62325],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ff5468e161daefa3c3300dd650d8ee1 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var marker_84acdaa3868a9c575a16c3272c92acba = L.marker(
#                 [41.802665, -87.613657],
#                 {}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var div_icon_ce68c200632d0b772604c73c110b9d3d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:20pt; color:red\&quot;\u003eMichelle Obama\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 8], &quot;iconSize&quot;: [100, 0]});
#             marker_84acdaa3868a9c575a16c3272c92acba.setIcon(div_icon_ce68c200632d0b772604c73c110b9d3d);
#
#
#             var circle_marker_2fdceba18687e0ff7a71a2e33510aa54 = L.circleMarker(
#                 [41.802665, -87.613657],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var marker_d8d031a4c826b2b18b44def38aa301eb = L.marker(
#                 [41.8631, -87.6231],
#                 {}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var div_icon_45ddc11d07c8a9503fc214be2df5d2f1 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:20pt; color:red\&quot;\u003eRobin Williams\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 8], &quot;iconSize&quot;: [100, 0]});
#             marker_d8d031a4c826b2b18b44def38aa301eb.setIcon(div_icon_45ddc11d07c8a9503fc214be2df5d2f1);
#
#
#             var circle_marker_60aa1ad1e8afb836ab50e98d8a12afdc = L.circleMarker(
#                 [41.8631, -87.6231],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var marker_e1d27ba378dce57370376718bbf73056 = L.marker(
#                 [41.907879, -87.732594],
#                 {}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var div_icon_a29507003960a657a1aa76c594e061ef = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:20pt; color:red\&quot;\u003eWalt Disney\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 8], &quot;iconSize&quot;: [100, 0]});
#             marker_e1d27ba378dce57370376718bbf73056.setIcon(div_icon_a29507003960a657a1aa76c594e061ef);
#
#
#             var circle_marker_fe10957623bd5796ae4740f5b9d6c436 = L.circleMarker(
#                 [41.907879, -87.732594],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9281869bf14b84cd9b4d63b1f

# %% [markdown]
# Map tiles by Stamen Design Data by (c)Open Street Map
#
# Q3. What side of the city was Michelle Obama born?
# <hr>
# <h3>STEP FOUR</h3>
# Let's make a function which can add another person to our dataframe called Chi

# %%
def addperson(map_name,df,name,age,alive,noted,birth,zipcode,lat,lon,fact):
    our_map=map_name 
    new_row = {'Name':name, 
                   'Age':age, 
                   'Alive':alive,
                   'Noted For':noted,
                    'Place of Birth':birth,
                    'Zip':zipcode,
                    'Lat':lat,
                    'Lon':lon,
                    'fun fact':fact            }
    df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
    i=len(df)-1
    p=[df.loc[i,"Lat"],df.loc[i,"Lon"]]
    folium.Marker(p,icon=DivIcon(
        icon_size=(100,0),
        icon_anchor=(0,8),
        html='<div style="font-size: 15pt; color : blue">'+str(df.loc[i,"Name"]) +'</div>',
            )).add_to(our_map)
    our_map.add_child(folium.CircleMarker(p, radius=1,color='red'))
    return df,our_map

# %% [markdown]
# Q4. What command is used to add a new line to the dataframe df?
# <hr>

# %% [markdown]
# <h3>STEP FIVE</h3>
# Let's add Jenifer Hudson to our dataframe using the following info:
#
# 'Jennifer Hudson',38,'yes','Actress','Englewood',60621,41.779699,-87.633194,'worked at Burger King'

# %%
[Chi,Chicago_map]=addperson(Chicago_map,Chi,'Jennifer Hudson','Actress',41,'yes','Englewood',60621,41.779699,-87.633194,'worked at Burger King')
Chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9281869bf14b84cd9b4d63b1fc723c0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9281869bf14b84cd9b4d63b1fc723c0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9281869bf14b84cd9b4d63b1fc723c0f = L.map(
#                 &quot;map_9281869bf14b84cd9b4d63b1fc723c0f&quot;,
#                 {
#                     center: [41.886456, -87.62325],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ff5468e161daefa3c3300dd650d8ee1 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var marker_84acdaa3868a9c575a16c3272c92acba = L.marker(
#                 [41.802665, -87.613657],
#                 {}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var div_icon_ce68c200632d0b772604c73c110b9d3d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:20pt; color:red\&quot;\u003eMichelle Obama\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 8], &quot;iconSize&quot;: [100, 0]});
#             marker_84acdaa3868a9c575a16c3272c92acba.setIcon(div_icon_ce68c200632d0b772604c73c110b9d3d);
#
#
#             var circle_marker_2fdceba18687e0ff7a71a2e33510aa54 = L.circleMarker(
#                 [41.802665, -87.613657],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var marker_d8d031a4c826b2b18b44def38aa301eb = L.marker(
#                 [41.8631, -87.6231],
#                 {}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var div_icon_45ddc11d07c8a9503fc214be2df5d2f1 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:20pt; color:red\&quot;\u003eRobin Williams\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 8], &quot;iconSize&quot;: [100, 0]});
#             marker_d8d031a4c826b2b18b44def38aa301eb.setIcon(div_icon_45ddc11d07c8a9503fc214be2df5d2f1);
#
#
#             var circle_marker_60aa1ad1e8afb836ab50e98d8a12afdc = L.circleMarker(
#                 [41.8631, -87.6231],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var marker_e1d27ba378dce57370376718bbf73056 = L.marker(
#                 [41.907879, -87.732594],
#                 {}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var div_icon_a29507003960a657a1aa76c594e061ef = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:20pt; color:red\&quot;\u003eWalt Disney\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 8], &quot;iconSize&quot;: [100, 0]});
#             marker_e1d27ba378dce57370376718bbf73056.setIcon(div_icon_a29507003960a657a1aa76c594e061ef);
#
#
#             var circle_marker_fe10957623bd5796ae4740f5b9d6c436 = L.circleMarker(
#                 [41.907879, -87.732594],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9281869bf14b84cd9b4d63b1f

# %% [markdown]
# Map tiles by Stamen Design Data by (c)Open Street Map
#
# Q5. Where did Jennifer Hudson work before becoming famous?
# <hr>
# <h3>STEP SIX</h3>
# Add your info to the map by editing the info in the next cell.

# %%
#answer to Step Six

# %% [markdown]
# <h3> STEP SEVEN</h3>
# Let's save your map and info in a new Excel file.

# %%
Chicago_map.save("Chicagoans.html")
Chi.to_excel('ChiRevised.xlsx')

# %% [markdown]
# Q7. Did your map display correctly?  Did the new Excel file include your name?
# <hr>

# %% [markdown]
# <h4> For Discussion </h4>
# a) Whom do you admire?  Why so?
# <hr>
# b)  What character qualities can help someone to be successful in life?
# <hr>
# c) What can help you to be more successful?
# <hr>

# %% [markdown]
# #### Solutions

# %% [markdown]
# Q1) 15
#
# Q2) Increasing the zoom_start value zooms in on the specified location. Changing the numbers in location changes the lat,lon of the zoom position.
#
# Q3) South Side
#
# Q4) new_info and df.append in lines 3-12
#
# Q5) Burger King

# %%
# Q6
[Chi,Chicago_map]=addperson(Chicago_map,Chi,'Lorraine Hansberry','Writer',34,'no','Provident Hospital',60615,41.80287,-87.61325,'studied painting in Mexico')
Chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9281869bf14b84cd9b4d63b1fc723c0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9281869bf14b84cd9b4d63b1fc723c0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9281869bf14b84cd9b4d63b1fc723c0f = L.map(
#                 &quot;map_9281869bf14b84cd9b4d63b1fc723c0f&quot;,
#                 {
#                     center: [41.886456, -87.62325],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ff5468e161daefa3c3300dd650d8ee1 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var marker_84acdaa3868a9c575a16c3272c92acba = L.marker(
#                 [41.802665, -87.613657],
#                 {}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var div_icon_ce68c200632d0b772604c73c110b9d3d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:20pt; color:red\&quot;\u003eMichelle Obama\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 8], &quot;iconSize&quot;: [100, 0]});
#             marker_84acdaa3868a9c575a16c3272c92acba.setIcon(div_icon_ce68c200632d0b772604c73c110b9d3d);
#
#
#             var circle_marker_2fdceba18687e0ff7a71a2e33510aa54 = L.circleMarker(
#                 [41.802665, -87.613657],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var marker_d8d031a4c826b2b18b44def38aa301eb = L.marker(
#                 [41.8631, -87.6231],
#                 {}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var div_icon_45ddc11d07c8a9503fc214be2df5d2f1 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:20pt; color:red\&quot;\u003eRobin Williams\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 8], &quot;iconSize&quot;: [100, 0]});
#             marker_d8d031a4c826b2b18b44def38aa301eb.setIcon(div_icon_45ddc11d07c8a9503fc214be2df5d2f1);
#
#
#             var circle_marker_60aa1ad1e8afb836ab50e98d8a12afdc = L.circleMarker(
#                 [41.8631, -87.6231],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var marker_e1d27ba378dce57370376718bbf73056 = L.marker(
#                 [41.907879, -87.732594],
#                 {}
#             ).addTo(map_9281869bf14b84cd9b4d63b1fc723c0f);
#
#
#             var div_icon_a29507003960a657a1aa76c594e061ef = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:20pt; color:red\&quot;\u003eWalt Disney\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 8], &quot;iconSize&quot;: [100, 0]});
#             marker_e1d27ba378dce57370376718bbf73056.setIcon(div_icon_a29507003960a657a1aa76c594e061ef);
#
#
#             var circle_marker_fe10957623bd5796ae4740f5b9d6c436 = L.circleMarker(
#                 [41.907879, -87.732594],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9281869bf14b84cd9b4d63b1f

# %%
Chi
# Out:
#                  Name      Age Alive      Noted For           Place of Birth  \
# 0      Michelle Obama       56   yes     First Lady       Provident Hospital
# 1      Robin Williams       63    no          Actor       St Luke's Hospital
# 2         Walt Disney       65    no  Film Producer            149 Tripp Ave
# 3       Bobby Fischer       64    no          Chess  Michael Reese  Hospital
# 4        Isiah Thomas       59   yes     Basketball                West Side
# 5     Jennifer Hudson  Actress    41            yes                Englewood
# 6  Lorraine Hansberry   Writer    34             no       Provident Hospital
#
#      Zip        Lat        Lon                                 fun fact
# 0  60605  41.802665 -87.613657        father worked at city water plant
# 1  60605  41.863100 -87.623100  went to Julliard with Christopher Reeve
# 2  60651  41.907879 -87.732594                            won 22 oscars
# 3  60606  41.884116 -87.637656                    grandmaster at age 15
# 4  60624  41.874827 -87.710075                   youngest of 9 children
# 5  60621  41.779699 -87.633194                    worked at Burger King
# 6  60615  41.802870 -87.613250               studied painting in Mexico
